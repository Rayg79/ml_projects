# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Videos\\assets\\practice'

# %%
path = "\\Users\\KENUKON\\Videos\\assets\\practice"

# %%
os.chdir(path)

# %%
data = pd.read_csv('all_student.csv')

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+
# 0   | id | First Name | Last Name | Age |  State  ...
# 1   +----+------------+-----------+-----+---------...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
# 12  +----+------------+-----------+-----+---------...

# %%
data.columns
# Out:
# Index(['+----+------------+-----------+-----+---------+------------------+-------+--------+'], dtype='object')

# %%
data.drop([1,12], axis = 0, inplace= True)

# %%
data['id'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[1])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id
# 0    id
# 2    1
# 3    2
# 4    3
# 5    4
# 6    5
# 7    6
# 8    7
# 9    8
# 10   9
# 11   10

# %%
data['first_name'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[2])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id    first_name
# 0    id    First Name
# 2    1      Micheal
# 3    2       Ishola
# 4    3       Grace
# 5    4       Adamu
# 6    5      Gabriel
# 7    6       Ngozie
# 8    7        Jude
# 9    8        Mery
# 10   9      Jinjiri
# 11   10      Aisha

# %%
data['last_name'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[3])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id    first_name    last_name
# 0    id    First Name    Last Name
# 2    1      Micheal         Uche
# 3    2       Ishola        Adams
# 4    3       Grace         James
# 5    4       Adamu          Bala
# 6    5      Gabriel        Ezikel
# 7    6       Ngozie        Bright
# ...

# %%
data['age'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[4])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id    first_name    last_name    age
# 0    id    First Name    Last Name    Age
# 2    1      Micheal         Uche       22
# 3    2       Ishola        Adams       18
# 4    3       Grace         James       20
# 5    4       Adamu          Bala       22
# ...

# %%
data['State'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[5])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id    first_name    last_name    age      State
# 0    id    First Name    Last Name    Age     State
# 2    1      Micheal         Uche       22      Abia
# 3    2       Ishola        Adams       18      Osun
# 4    3       Grace         James       20     Lagos
# ...

# %%
data['department'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[6])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id    first_name    last_name    age      State          Department
# 0    id    First Name    Last Name    Age     State        Department
# 2    1      Micheal         Uche       22      Abia      Computer Dept
# ...

# %%
data['level'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[7])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id    first_name    last_name    age      State          Department  \
# 0    id    First Name    Last Name    Age     State        Department
# 2    1      Micheal         Uche       22      Abia      Computer Dept
# ...

# %%
data['gender'] = data['+----+------------+-----------+-----+---------+------------------+-------+--------+'].apply(lambda x: x.split('|')[8])

# %%
data
# Out:
#    +----+------------+-----------+-----+---------+------------------+-------+--------+  \
# 0   | id | First Name | Last Name | Age |  State  ...
# 2   | 1  |  Micheal   |    Uche   |  22 |   Abia  ...
# 3   | 2  |   Ishola   |   Adams   |  18 |   Osun  ...
# 4   | 3  |   Grace    |   James   |  20 |  Lagos  ...
# 5   | 4  |   Adamu    |    Bala   |  22 |   Kano  ...
# 6   | 5  |  Gabriel   |   Ezikel  |  20 |   Abia  ...
# 7   | 6  |   Ngozie   |   Bright  |  21 | Anambra ...
# 8   | 7  |    Jude    |  Ogunowo  |  20 |  Lagos  ...
# 9   | 8  |    Mery    |   Okezie  |  21 |   Abia  ...
# 10  | 9  |  Jinjiri   |   Sadan   |  20 |   Kano  ...
# 11  | 10 |   Aisha    |   Oseni   |  23 |  Jigawa ...
#
#       id    first_name    last_name    age      State          Department  \
# 0    id    First Name    Last Name    Age     State        Department
# 2    1      Micheal         Uche       22      Abia      Computer Dept
# ...

# %%
data.drop(['+----+------------+-----------+-----+---------+------------------+-------+--------+'], axis = 1, inplace = True)

# %%
data.drop(0, inplace = True)

# %%
data
# Out:
#       id    first_name    last_name    age      State          Department  \
# 2    1      Micheal         Uche       22      Abia      Computer Dept
# 3    2       Ishola        Adams       18      Osun     Mathematics Dept
# 4    3       Grace         James       20     Lagos     Statistics Dept
# 5    4       Adamu          Bala       22      Kano      Computer Dept
# 6    5      Gabriel        Ezikel      20      Abia     Mathematics Dept
# 7    6       Ngozie        Bright      21    Anambra    Statistics Dept
# 8    7        Jude        Ogunowo      20     Lagos     statistics Dept
# 9    8        Mery         Okezie      21      Abia      Computer Dept
# 10   9      Jinjiri        Sadan       20      Kano     Mathematics Dept
# 11   10      Aisha         Oseni       23     Jigawa     Computer Dept
#
#       level    gender
# 2     300      Male
# 3     200      Male
# 4     100     Female
# 5     200      Male
# 6     100      Male
# 7     300     Female
# 8     200      Male
# ...

# %%
okdata = data

# %%
okdata.to_csv('workable.csv', index = False)
