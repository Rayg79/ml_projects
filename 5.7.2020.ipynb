# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON'

# %%
path = "\\Users\\KENUKON\\Videos\\assets\\practice"

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Videos\\assets\\practice'

# %%
data = pd.read_csv('workable.csv')

# %%
data
# Out:
#    id    first_name    last_name  age      State          Department  level  \
# 0   1    Micheal         Uche      22     Abia      Computer Dept       300
# 1   2     Ishola        Adams      18     Osun     Mathematics Dept     200
# 2   3     Grace         James      20    Lagos     Statistics Dept      100
# 3   4     Adamu          Bala      22     Kano      Computer Dept       200
# 4   5    Gabriel        Ezikel     20     Abia     Mathematics Dept     100
# 5   6     Ngozie        Bright     21   Anambra    Statistics Dept      300
# 6   7      Jude        Ogunowo     20    Lagos     statistics Dept      200
# 7   8      Mery         Okezie     21     Abia      Computer Dept       100
# 8   9    Jinjiri        Sadan      20     Kano     Mathematics Dept     100
# 9  10     Aisha         Oseni      23    Jigawa     Computer Dept       200
#
#      gender
# 0    Male
# 1    Male
# 2   Female
# 3    Male
# 4    Male
# 5   Female
# 6    Male
# 7   Female
# 8    Male
# ...

# %%
data.query("age == 21")
# Out:
#    id    first_name    last_name  age      State          Department  level  \
# 5   6     Ngozie        Bright     21   Anambra    Statistics Dept      300
# 7   8      Mery         Okezie     21     Abia      Computer Dept       100
#
#      gender
# 5   Female
# 7   Female

# %%
data[data["a"] == 'Kano']
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, age, State, Department, level, gender]
# Index: []

# %%
data
# Out:
#    id    first_name    last_name  age      State          Department  level  \
# 0   1    Micheal         Uche      22     Abia      Computer Dept       300
# 1   2     Ishola        Adams      18     Osun     Mathematics Dept     200
# 2   3     Grace         James      20    Lagos     Statistics Dept      100
# 3   4     Adamu          Bala      22     Kano      Computer Dept       200
# 4   5    Gabriel        Ezikel     20     Abia     Mathematics Dept     100
# 5   6     Ngozie        Bright     21   Anambra    Statistics Dept      300
# 6   7      Jude        Ogunowo     20    Lagos     statistics Dept      200
# 7   8      Mery         Okezie     21     Abia      Computer Dept       100
# 8   9    Jinjiri        Sadan      20     Kano     Mathematics Dept     100
# 9  10     Aisha         Oseni      23    Jigawa     Computer Dept       200
#
#      gender
# 0    Male
# 1    Male
# 2   Female
# 3    Male
# 4    Male
# 5   Female
# 6    Male
# 7   Female
# 8    Male
# ...

# %%
data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'age', 'State', 'Department', 'level',
#        'gender'],
#       dtype='object')

# %%
data.columns = ['id', 'first_name', 'last_name', 'age', 'state', 'department', 'level',
       'gender']

# %%
data
# Out:
#    id    first_name    last_name  age      state          department  level  \
# 0   1    Micheal         Uche      22     Abia      Computer Dept       300
# 1   2     Ishola        Adams      18     Osun     Mathematics Dept     200
# 2   3     Grace         James      20    Lagos     Statistics Dept      100
# 3   4     Adamu          Bala      22     Kano      Computer Dept       200
# 4   5    Gabriel        Ezikel     20     Abia     Mathematics Dept     100
# 5   6     Ngozie        Bright     21   Anambra    Statistics Dept      300
# 6   7      Jude        Ogunowo     20    Lagos     statistics Dept      200
# 7   8      Mery         Okezie     21     Abia      Computer Dept       100
# 8   9    Jinjiri        Sadan      20     Kano     Mathematics Dept     100
# 9  10     Aisha         Oseni      23    Jigawa     Computer Dept       200
#
#      gender
# 0    Male
# 1    Male
# 2   Female
# 3    Male
# 4    Male
# 5   Female
# 6    Male
# 7   Female
# 8    Male
# ...

# %%
data[data['state'] == 'Abia']
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, age, state, department, level, gender]
# Index: []

# %%
data.describe()
# Out:
#              id        age       level
# count  10.00000  10.000000   10.000000
# mean    5.50000  20.700000  180.000000
# std     3.02765   1.418136   78.881064
# min     1.00000  18.000000  100.000000
# 25%     3.25000  20.000000  100.000000
# 50%     5.50000  20.500000  200.000000
# 75%     7.75000  21.750000  200.000000
# max    10.00000  23.000000  300.000000

# %%
data
# Out:
#    id    first_name    last_name  age      State          Department  level  \
# 0   1    Micheal         Uche      22     Abia      Computer Dept       300
# 1   2     Ishola        Adams      18     Osun     Mathematics Dept     200
# 2   3     Grace         James      20    Lagos     Statistics Dept      100
# 3   4     Adamu          Bala      22     Kano      Computer Dept       200
# 4   5    Gabriel        Ezikel     20     Abia     Mathematics Dept     100
# 5   6     Ngozie        Bright     21   Anambra    Statistics Dept      300
# 6   7      Jude        Ogunowo     20    Lagos     statistics Dept      200
# 7   8      Mery         Okezie     21     Abia      Computer Dept       100
# 8   9    Jinjiri        Sadan      20     Kano     Mathematics Dept     100
# 9  10     Aisha         Oseni      23    Jigawa     Computer Dept       200
#
#      gender
# 0    Male
# 1    Male
# 2   Female
# 3    Male
# 4    Male
# 5   Female
# 6    Male
# 7   Female
# 8    Male
# ...

# %%
data["age"] = pd.to_numeric(data["age"])

# %%
data
# Out:
#    id    first_name    last_name  age      State          Department  level  \
# 0   1    Micheal         Uche      22     Abia      Computer Dept       300
# 1   2     Ishola        Adams      18     Osun     Mathematics Dept     200
# 2   3     Grace         James      20    Lagos     Statistics Dept      100
# 3   4     Adamu          Bala      22     Kano      Computer Dept       200
# 4   5    Gabriel        Ezikel     20     Abia     Mathematics Dept     100
# 5   6     Ngozie        Bright     21   Anambra    Statistics Dept      300
# 6   7      Jude        Ogunowo     20    Lagos     statistics Dept      200
# 7   8      Mery         Okezie     21     Abia      Computer Dept       100
# 8   9    Jinjiri        Sadan      20     Kano     Mathematics Dept     100
# 9  10     Aisha         Oseni      23    Jigawa     Computer Dept       200
#
#      gender
# 0    Male
# 1    Male
# 2   Female
# 3    Male
# 4    Male
# 5   Female
# 6    Male
# 7   Female
# 8    Male
# ...

# %%
data["age"].describe()
# Out:
# count    10.000000
# mean     20.700000
# std       1.418136
# min      18.000000
# 25%      20.000000
# 50%      20.500000
# 75%      21.750000
# max      23.000000
# Name: age, dtype: float64

# %%
np.average(data["age"])
# Out:
# 20.7
