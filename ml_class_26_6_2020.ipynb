# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = {'name':['Olugbenga', 'Olushola', 'Titilayo', 'Omotola'],
        'score': [69,5,8,20],
        'postion':[7,1.1,6,5]
       }
arr1 = {'A': [1,3,6,8],
        'B': [2,7,9,0],
        'C': [5,7,2,4],
        'D': [np.nan,3,4,7]
       }
arr2 = {'A': [5,np.nan,6,8],
        'B': [2,7,9,6],
        'C': [5,4,2,4],
        'D': [8,3,1,7]
       }
arr3 = {'A': [np.nan,3,8,np.nan],
        'B': [2,7,0,3],
        'C': [5,7,np.nan,4],
        'D': [np.nan,3,6,np.nan]
       }
ind = ['U', 'V','W','X']

# %%
df = pd.DataFrame(data)
df1 = pd.DataFrame(data = arr1, index = ind)
df2 = pd.DataFrame(data = arr2, index = ind)
df3 = pd.DataFrame(data = arr3, index = ind)

# %%
df2
# Out:
#      A  B  C  D
# U  5.0  2  5  8
# V  NaN  7  4  3
# W  6.0  9  2  1
# X  8.0  6  4  7

# %%
df2[['C']]
# Out:
#    C
# U  5
# V  4
# W  2
# X  4

# %%
df2['C']
# Out:
# U    5
# V    4
# W    2
# X    4
# Name: C, dtype: int64

# %%
df2.iloc[2]
# Out:
# A    6.0
# B    9.0
# C    2.0
# D    1.0
# Name: W, dtype: float64

# %%
df2.loc['W']
# Out:
# A    6.0
# B    9.0
# C    2.0
# D    1.0
# Name: W, dtype: float64

# %%
df2[['A','B']]
# Out:
#      A  B
# U  5.0  2
# V  NaN  7
# W  6.0  9
# X  8.0  6

# %%
df2.dropna()
# Out:
#      A  B  C  D
# U  5.0  2  5  8
# W  6.0  9  2  1
# X  8.0  6  4  7

# %%
df3
# Out:
#      A  B    C    D
# U  NaN  2  5.0  NaN
# V  3.0  7  7.0  3.0
# W  8.0  0  NaN  6.0
# X  NaN  3  4.0  NaN

# %%
df3.dropna(thresh=3)
# Out:
#      A  B    C    D
# V  3.0  7  7.0  3.0
# W  8.0  0  NaN  6.0

# %%
df3
# Out:
#      A  B    C    D
# U  NaN  2  5.0  NaN
# V  3.0  7  7.0  3.0
# W  8.0  0  NaN  6.0
# X  NaN  3  4.0  NaN

# %%
df3.isnull()
# Out:
#        A      B      C      D
# U   True  False  False   True
# V  False  False  False  False
# W  False  False   True  False
# X   True  False  False   True

# %%
df3['A'].count()
# Out:
# 2

# %%
df3.sort_values('B')
# Out:
#      A  B    C    D
# W  8.0  0  NaN  6.0
# U  NaN  2  5.0  NaN
# X  NaN  3  4.0  NaN
# V  3.0  7  7.0  3.0

# %%
li = [df1,df2,df3]

# %%
li
# Out:
# [   A  B  C    D
#  U  1  2  5  NaN
#  V  3  7  7  3.0
#  W  6  9  2  4.0
#  X  8  0  4  7.0,
#       A  B  C  D
#  U  5.0  2  5  8
#  V  NaN  7  4  3
#  W  6.0  9  2  1
#  X  8.0  6  4  7,
#       A  B    C    D
#  U  NaN  2  5.0  NaN
#  V  3.0  7  7.0  3.0
#  W  8.0  0  NaN  6.0
#  X  NaN  3  4.0  NaN]

# %%
cont = pd.concat(li)

# %%
cont
# Out:
#      A  B    C    D
# U  1.0  2  5.0  NaN
# V  3.0  7  7.0  3.0
# W  6.0  9  2.0  4.0
# X  8.0  0  4.0  7.0
# U  5.0  2  5.0  8.0
# V  NaN  7  4.0  3.0
# W  6.0  9  2.0  1.0
# X  8.0  6  4.0  7.0
# U  NaN  2  5.0  NaN
# V  3.0  7  7.0  3.0
# W  8.0  0  NaN  6.0
# X  NaN  3  4.0  NaN

# %%
cont2 = pd.concat([df1,df2,df3], axis = 1)

# %%
cont2
# Out:
#    A  B  C    D    A  B  C  D    A  B    C    D
# U  1  2  5  NaN  5.0  2  5  8  NaN  2  5.0  NaN
# V  3  7  7  3.0  NaN  7  4  3  3.0  7  7.0  3.0
# W  6  9  2  4.0  6.0  9  2  1  8.0  0  NaN  6.0
# X  8  0  4  7.0  8.0  6  4  7  NaN  3  4.0  NaN

# %%
cont2.dropna(thresh = 3)
# Out:
#    A  B  C    D    A  B  C  D    A  B    C    D
# U  1  2  5  NaN  5.0  2  5  8  NaN  2  5.0  NaN
# V  3  7  7  3.0  NaN  7  4  3  3.0  7  7.0  3.0
# W  6  9  2  4.0  6.0  9  2  1  8.0  0  NaN  6.0
# X  8  0  4  7.0  8.0  6  4  7  NaN  3  4.0  NaN

# %%
df3
# Out:
#      A  B    C    D
# U  NaN  2  5.0  NaN
# V  3.0  7  7.0  3.0
# W  8.0  0  NaN  6.0
# X  NaN  3  4.0  NaN

# %%
df3['Mult'] = df3['A'] * df3['D']

# %%
df3
# Out:
#      A  B    C    D  Mult
# U  NaN  2  5.0  NaN   NaN
# V  3.0  7  7.0  3.0   9.0
# W  8.0  0  NaN  6.0  48.0
# X  NaN  3  4.0  NaN   NaN

# %%
def multiple(x):
    return x * 3

# %%
multiple(5)
# Out:
# 15

# %%
df3
# Out:
#      A  B    C    D  Mult
# U  NaN  2  5.0  NaN   NaN
# V  3.0  7  7.0  3.0   9.0
# W  8.0  0  NaN  6.0  48.0
# X  NaN  3  4.0  NaN   NaN

# %%
df3["B"]
# Out:
# U    2
# V    7
# W    0
# X    3
# Name: B, dtype: int64

# %%
df3['B'].apply(multiple)
# Out:
# U     6
# V    21
# W     0
# X     9
# Name: B, dtype: int64

# %%
df3['B'].apply(lambda i: i* 4)
# Out:
# U     8
# V    28
# W     0
# X    12
# Name: B, dtype: int64

# %%
array = [200,700,200,370,200]

# %%
dfi = pd.DataFrame(array)
dfi
# Out:
#      0
# 0  200
# 1  700
# 2  200
# 3  370
# 4  200

# %%
dfi[0].unique()
# Out:
# array([200, 700, 370], dtype=int64)

# %%
dfi[0].value_counts()
# Out:
# 200    3
# 700    1
# 370    1
# Name: 0, dtype: int64

# %%
dfi[0].nunique()
# Out:
# 3

# %%
data = pd.read_csv("nba.csv")

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.head(20)
# Out:
#                        Name            Team  Number Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1               Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2              John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3               R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4             Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 5              Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 6             Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 7              Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 8              Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 9              Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# ...

# %%
data.tail(20)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 438    Luis Montero  Portland Trail Blazers    44.0       SG  23.0    6-7
# 439   Mason Plumlee  Portland Trail Blazers    24.0        C  26.0   6-11
# 440   Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 441     Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 442   Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# 443      Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 444      Alec Burks               Utah Jazz    10.0       SG  24.0    6-6
# 445      Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 446  Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 447     Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 448  Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
# 449     Rodney Hood               Utah Jazz     5.0       SG  23.0    6-8
# ...

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data['Team'].nunique()
# Out:
# 30

# %%
data['Salary'].max()
# Out:
# 25000000.0

# %%
grpTeam = data.groupby('Team')

# %%
grpTeam.sum()
# Out:
#                         Number    Age  Weight       Salary
# Team
# Atlanta Hawks            285.0  423.0  3319.0   72902950.0
# Boston Celtics           478.0  371.0  3292.0   58541068.0
# Brooklyn Nets            274.0  384.0  3234.0   52528475.0
# Charlotte Hornets        257.0  392.0  3306.0   78340920.0
# Chicago Bulls            288.0  411.0  3284.0   86783378.0
# Cleveland Cavaliers      217.0  443.0  3418.0  106988689.0
# Dallas Mavericks         300.0  446.0  3405.0   71198732.0
# Denver Nuggets           229.0  386.0  3263.0   60121930.0
# Detroit Pistons          259.0  393.0  3333.0   67168263.0
# Golden State Warriors    313.0  415.0  3369.0   88868997.0
# Houston Rockets          220.0  403.0  3305.0   75283021.0
# Indiana Pacers           284.0  396.0  3334.0   66751826.0
# Los Angeles Clippers     293.0  442.0  3296.0   94854640.0
# Los Angeles Lakers       241.0  413.0  3406.0   71770431.0
# Memphis Grizzlies        280.0  511.0  3924.0   76550880.0
# ...

# %%
grpTeam.all()
# Out:
#                         Name  Number  Position   Age  Height  Weight  College  \
# Team
# Atlanta Hawks           True   False      True  True    True    True     True
# Boston Celtics          True   False      True  True    True    True     True
# Brooklyn Nets           True   False      True  True    True    True     True
# Charlotte Hornets       True   False      True  True    True    True     True
# Chicago Bulls           True   False      True  True    True    True     True
# Cleveland Cavaliers     True   False      True  True    True    True     True
# Dallas Mavericks        True    True      True  True    True    True     True
# Denver Nuggets          True   False      True  True    True    True     True
# Detroit Pistons         True   False      True  True    True    True     True
# Golden State Warriors   True    True      True  True    True    True     True
# Houston Rockets         True   False      True  True    True    True     True
# ...

# %%
grpTeam.count()
# Out:
#                         Name  Number  Position  Age  Height  Weight  College  \
# Team
# Atlanta Hawks             15      15        15   15      15      15       11
# Boston Celtics            15      15        15   15      15      15       13
# Brooklyn Nets             15      15        15   15      15      15       13
# Charlotte Hornets         15      15        15   15      15      15       13
# Chicago Bulls             15      15        15   15      15      15       12
# Cleveland Cavaliers       15      15        15   15      15      15       12
# Dallas Mavericks          15      15        15   15      15      15       12
# Denver Nuggets            15      15        15   15      15      15        9
# Detroit Pistons           15      15        15   15      15      15       15
# Golden State Warriors     15      15        15   15      15      15       12
# Houston Rockets           15      15        15   15      15      15       11
# ...

# %%
grpTeam['name'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-db2b53d20954> in <module>
# ----> 1 grpTeam['name'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1611                 stacklevel=2,
#    1612             )
# -> 1613         return super().__getitem__(key)
#    1614
#    1615     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     237         else:
#     238             if key not in self.obj:
# --> 239                 raise KeyError(f"Column not found: {key}")
#     240             return self._gotitem(key, ndim=1)
#     241
#
# KeyError: 'Column not found: name'

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.dropna(subset = ['College'])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...
