# %%
# the first import is an import of chart plotter from matplotlib 
import matplotlib.pyplot as plt

# converting the numpy import to a short name
import numpy as np

# calling a line for the chart in matplotlib
# %matplotlib inline

# calling pillow library that caries image
from PIL import Image

# it is use to read file and copy file path into our project
import glob

import os

import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-69-4155736cda06> in <module>
#      16 import os
#      17
# ---> 18 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
#       - os.altsep is the alternate pathname separator (None or '/')
#       - os.pathsep is the component separator used in $PATH etc
#       - os.linesep is the line separator in text files ('\r' or '\n' or '\r\n')
#       - os.defpath is the default search path for executables
#       - os.devnull is the file path of the null device ('/dev/null', etc.)
#
# ...

# %%
# get the current windows directory
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\path\\resized'

# %%
# path = "/Users/KENUKON/"
path2 = "\\Users\\KENUKON\\Desktop\\path"

# %%
# chdir helps to change the os directory
os.chdir(path2)

# %%
# get the current windows directory
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\path'

# %%
# creating a directory in the currrent windows directory
os.mkdir('Gbenga')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-75-87ac254d581a> in <module>
#       1 # creating a directory in the currrent windows directory
# ----> 2 os.mkdir('Gbenga')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Gbenga'

# %%
# display the list of directory from the current window directory
os.listdir()
# Out:
# ['Gbenga', 'resized']

# %%
# rmdir is use to delect directory from the current window directory
os.rmdir('Gbenga')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-77-fc3552a00275> in <module>
#       1 # rmdir is use to delect directory from the current window directory
# ----> 2 os.rmdir('Gbenga')
#
# OSError: [WinError 145] The directory is not empty: 'Gbenga'

# %%
os.listdir()
# Out:
# ['Gbenga', 'resized']

# %%
# creating a directory in the currrent windows directory
os.mkdir('Gbenga')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-79-87ac254d581a> in <module>
#       1 # creating a directory in the currrent windows directory
# ----> 2 os.mkdir('Gbenga')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Gbenga'

# %%
path3 = "\\Users\\KENUKON\\Desktop\\path\\Gbenga\\1.jpg"
path4 = "\\Users\\KENUKON\\Desktop\\path\\Gbenga\\*.jpg"

# %%
# img = cv2.imread(path3)
# cv2.imshow('1.jpg', img)

# %%
pic_org = []
pic_res = []

# %%
for files in glob.glob(path4):
    img = Image.open(files)
    pic_org.append(img)

# %%
for images in pic_org:
    img1 = Img.resize((500,500))
    pic_res.append(img1)

# %%
pic_res
# Out:
# [<PIL.Image.Image image mode=RGB size=500x500 at 0x25AC593EA88>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x25AC593EE88>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x25AC88C6808>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x25ACA3390C8>]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\path'

# %%
#os.mkdir('resized')

# %%
# assign the resized path to a variable
new_path = '\\Users\\KENUKON\\Desktop\\path\\resized'

# %%
# changing the current window directory to the new path created 
os.chdir(new_path)

# %%
# call the function to see what 
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\path\\resized'

# %%
pic_res
# Out:
# [<PIL.Image.Image image mode=RGB size=500x500 at 0x25AC593EA88>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x25AC593EE88>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x25AC88C6808>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x25ACA3390C8>]

# %%
pic_org
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x718 at 0x25AC9EEEB08>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x718 at 0x25AC9EF4108>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x401 at 0x25AC9711F48>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5728x4000 at 0x25AC98E30C8>]

# %%
for(i,new) in enumerate(pic_res):
    new.save('{}{}{}'.format("\\Users\\KENUKON\\Desktop\\path\\resized\\pic", i+1, '.jpg'))

# %%
Image.open(path3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x718 at 0x25AC9D54388>

# %%
img4 = plt.imread(path3)
plt.imshow(img4)

# %%
img4.shape
# Out:
# (718, 1080, 3)

# %%
new.show()

# %%
pth = "\\Users\\KENUKON\\Desktop\\path\\cropped\\2.jpg"

# %%
img = plt.imread(pth)
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
im = Image.open(pth)

# %%
img.shape
# Out:
# (718, 1080, 3)

# %% [raw]
# cropped = im.crop((200,50,710,718))

# %%
cropped.show()

# %%
cropped.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-ba24fe35cd96> in <module>
# ----> 1 cropped.shape
#
# AttributeError: 'Image' object has no attribute 'shape'

# %%
import pandas as pd

# %%
df = pd.DataFrame(data = np.random.randn(1000), index = pd.date_range('22-06-2020', periods = 1000))
ts = pd.Series(data = np.random.randn(1000), index = pd.date_range('22-06-2020', periods = 1000))

# %%
df
# Out:
#                    0
# 2020-06-22 -1.299965
# 2020-06-23 -0.617667
# 2020-06-24 -0.442072
# 2020-06-25 -1.185399
# 2020-06-26 -1.836304
# ...              ...
# 2023-03-14  2.970804
# 2023-03-15 -1.124730
# 2023-03-16  1.042558
# 2023-03-17  1.385774
# 2023-03-18 -0.464309
#
# [1000 rows x 1 columns]

# %%
ts
# Out:
# 2020-06-22   -0.311298
# 2020-06-23    1.436094
# 2020-06-24    0.753381
# 2020-06-25    0.305002
# 2020-06-26    0.731371
#                 ...
# 2023-03-14   -1.634986
# 2023-03-15    0.937894
# 2023-03-16   -0.261368
# 2023-03-17    0.573873
# 2023-03-18   -0.270417
# Freq: D, Length: 1000, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
arr1 = np.array([[2,4,5,7], [4,7,9,1],[6,3,4,5]])
arr2 = np.array(['a','b','c','d'])
arr3 = np.array(['A','B','C'])

# %%
dfs = pd.DataFrame(data = arr1, index = arr3, columns = arr2)
dfs
# Out:
#    a  b  c  d
# A  2  4  5  7
# B  4  7  9  1
# C  6  3  4  5

# %%
arr1
# Out:
# array([[2, 4, 5, 7],
#        [4, 7, 9, 1],
#        [6, 3, 4, 5]])

# %%
dfs['a']
# Out:
# A    2
# B    4
# C    6
# Name: a, dtype: int32

# %%
type(dfs['a'])
# Out:
# pandas.core.series.Series

# %%
dfs.loc['A']
# Out:
# a    2
# b    4
# c    5
# d    7
# Name: A, dtype: int32

# %%
dfs.loc['A'].transpose()
# Out:
# a    2
# b    4
# c    5
# d    7
# Name: A, dtype: int32

# %%
dfs.iloc[-1]
# Out:
# a    6
# b    3
# c    4
# d    5
# Name: C, dtype: int32

# %%
dfs1 = pd.DataFrame(data = arr1, columns =arr2)

# %%
dfs1
# Out:
#    a  b  c  d
# 0  2  4  5  7
# 1  4  7  9  1
# 2  6  3  4  5

# %%
dfs1['sales'] = dfs1['a']*dfs1['c']

# %%
dfs1
# Out:
#    a  b  c  d  sales
# 0  2  4  5  7     10
# 1  4  7  9  1     36
# 2  6  3  4  5     24

# %%
dfs1.drop(1)
# Out:
#    a  b  c  d  sales
# 0  2  4  5  7     10
# 2  6  3  4  5     24

# %%
dfs1.drop(['b'], axis = 1)
# Out:
#    a  c  d  sales
# 0  2  5  7     10
# 1  4  9  1     36
# 2  6  4  5     24

# %%
dfs1['sales'].mean()
# Out:
# 23.333333333333332

# %%
dfs1['sales'].max()
# Out:
# 36

# %%
dfs1['sales'].describe()
# Out:
# count     3.000000
# mean     23.333333
# std      13.012814
# min      10.000000
# 25%      17.000000
# 50%      24.000000
# 75%      30.000000
# max      36.000000
# Name: sales, dtype: float64

# %%
dfs1.describe()
# Out:
#          a         b         c         d      sales
# count  3.0  3.000000  3.000000  3.000000   3.000000
# mean   4.0  4.666667  6.000000  4.333333  23.333333
# std    2.0  2.081666  2.645751  3.055050  13.012814
# min    2.0  3.000000  4.000000  1.000000  10.000000
# 25%    3.0  3.500000  4.500000  3.000000  17.000000
# 50%    4.0  4.000000  5.000000  5.000000  24.000000
# 75%    5.0  5.500000  7.000000  6.000000  30.000000
# max    6.0  7.000000  9.000000  7.000000  36.000000

# %%
dfs1
# Out:
#    a  b  c  d  sales
# 0  2  4  5  7     10
# 1  4  7  9  1     36
# 2  6  3  4  5     24
