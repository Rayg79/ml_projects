# %%
# the first import is an import of chart plotter from matplotlib 
import matplotlib.pyplot as plt

# converting the numpy import to a short name
import numpy as np

# calling a line for the chart in matplotlib
# %matplotlib inline

# calling pillow library that caries image
from PIL import Image

# it is use to read file and copy file path into our project
import glob

import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON'

# %%
path = "\\Users\\KENUKON\\Desktop\\assess"

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\assess'

# %%
os.mkdir('images')

# %%
new_path = "\\Users\\KENUKON\\Desktop\\assess\\images\\*.jpg"

# %%
os.listdir()
# Out:
# ['images', 'resize']

# %%
img_org = []
img_res = []
img_crop = []

# %%
for files in glob.glob(new_path):
    img = Image.open(files)
    img_org.append(img)

# %%
img_org
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=5752x4000 at 0x1B7ABBA9548>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x718 at 0x1B7ABC1B708>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x718 at 0x1B7ABC26CC8>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4928x3264 at 0x1B7ABC2A048>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x960 at 0x1B7ABC2A448>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x723 at 0x1B7ABC2F588>]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\assess'

# %%
os.mkdir('resize')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-15-5383ca12cbce> in <module>
# ----> 1 os.mkdir('resize')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'resize'

# %%
res_path = "\\Users\\KENUKON\\Desktop\\assess\\resize"

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\assess'

# %%
os.chdir(res_path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\assess\\resize'

# %%
for files in img_org:
    img1 = files.resize((500,500))
    img_res.append(img1)

# %%
img_res
# Out:
# [<PIL.Image.Image image mode=RGB size=500x500 at 0x1B7ABC53DC8>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x1B7ABC56B08>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x1B7ABC565C8>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x1B7ABC56C48>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x1B7ABC56CC8>,
#  <PIL.Image.Image image mode=RGB size=500x500 at 0x1B7ABC56D88>]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KENUKON\\Desktop\\assess\\resize'

# %%
for(i, new) in enumerate(img_res):
    new.save('{}{}{}'.format("\\Users\\KENUKON\\Desktop\\assess\\resize\\res_pic", i+1, '.jpg'))

# %%
img1_path = "\\Users\\KENUKON\\Desktop\\assess\\images\\1.jpg"
img2_path = "\\Users\\KENUKON\\Desktop\\assess\\images\\2.jpg"
img3_path = "\\Users\\KENUKON\\Desktop\\assess\\images\\3.jpg"
img4_path = "\\Users\\KENUKON\\Desktop\\assess\\images\\4.jpg"
img5_path = "\\Users\\KENUKON\\Desktop\\assess\\images\\5.jpg"
img6_path = "\\Users\\KENUKON\\Desktop\\assess\\images\\6.jpg"

# %%
img = plt.imread(img1_path)
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
im1 = Image.open(img1_path)
img.shape
# Out:
# (4000, 5752, 3)

# %%
cropped = im1.crop((0,500,5752,500))

# %%
cropped.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-33-8691515bb596> in <module>
# ----> 1 cropped.show()
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in show(self, title, command)
#    2144         """
#    2145
# -> 2146         _show(self, title=title, command=command)
#    2147
#    2148     def split(self):
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _show(image, **options)
#    3083 def _show(image, **options):
#    3084     # override me, as necessary
# ...
